# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
       # print(city_weather["weather"][0]['description'])
        # Parse out the needed data.
        city_lng = city_weather["coord"]["lon"]
        city_lat = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mbandaka
# Processing Record 2 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | mirnyy
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | aguimes
# Processing Record 7 of Set 1 | saint-ambroise
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | frome
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | muros
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | mount isa
# Processing Record 22 of Set 1 | beroroha
# Processing Record 23 of Set 1 | pacocha
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | pacific grove
# Processing Record 27 of Set 1 | sovetskiy
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | diego de almagro
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | pangody
# Processing Record 32 of Set 1 | hauterive
# Processing Record 33 of Set 1 | los llanos de aridane
# Processing Record 34 of Set 1 | moche
# Processing Record 35 of Set 1 | nemuro
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | makakilo city
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | la ronge
# Processing Record 49 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | eureka
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | sambava
# Processing Record 7 of Set 2 | bilibino
# Processing Record 8 of Set 2 | koumac
# Processing Record 9 of Set 2 | viedma
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | buraydah
# Processing Record 13 of Set 2 | shimoda
# Processing Record 14 of Set 2 | portland
# Processing Record 15 of Set 2 | yellamanchili
# City not found. Skipping...
# Processing Record 16 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 2 | lashio
# Processing Record 18 of Set 2 | sola
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | marawi
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | guarapari
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | lagoa
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | katima mulilo
# Processing Record 28 of Set 2 | massakory
# Processing Record 29 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 2 | sturgis
# Processing Record 31 of Set 2 | ankazobe
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | aquiraz
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | te anau
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | paamiut
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | rangia
# Processing Record 42 of Set 2 | roald
# Processing Record 43 of Set 2 | cockburn town
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | old town
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | bowen
# Processing Record 48 of Set 2 | karratha
# Processing Record 49 of Set 2 | svetlaya
# Processing Record 50 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | darnah
# Processing Record 5 of Set 3 | thaba-tseka
# Processing Record 6 of Set 3 | marsh harbour
# Processing Record 7 of Set 3 | manitouwadge
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | sucua
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | nylstroom
# City not found. Skipping...
# Processing Record 14 of Set 3 | yar-sale
# Processing Record 15 of Set 3 | gamba
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | chalus
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | haines junction
# Processing Record 20 of Set 3 | xining
# Processing Record 21 of Set 3 | goderich
# Processing Record 22 of Set 3 | bakchar
# Processing Record 23 of Set 3 | okahandja
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | tazovskiy
# Processing Record 30 of Set 3 | pozo colorado
# Processing Record 31 of Set 3 | brookline
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | bara
# Processing Record 35 of Set 3 | seoul
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | cabedelo
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | alta floresta
# Processing Record 41 of Set 3 | boz
# Processing Record 42 of Set 3 | jatni
# City not found. Skipping...
# Processing Record 43 of Set 3 | rio gallegos
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | amnat charoen
# Processing Record 46 of Set 3 | gallup
# Processing Record 47 of Set 3 | sanandaj
# Processing Record 48 of Set 3 | anloga
# Processing Record 49 of Set 3 | husavik
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | iqaluit
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | paita
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | inongo
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | bandarbeyla
# Processing Record 9 of Set 4 | port macquarie
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | ust-maya
# Processing Record 12 of Set 4 | quatre cocos
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | gat
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | bontang
# Processing Record 20 of Set 4 | biak
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | suntar
# Processing Record 25 of Set 4 | chino valley
# Processing Record 26 of Set 4 | inirida
# Processing Record 27 of Set 4 | nampa
# Processing Record 28 of Set 4 | ulundurpettai
# City not found. Skipping...
# Processing Record 29 of Set 4 | sur
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | carberry
# Processing Record 32 of Set 4 | tual
# Processing Record 33 of Set 4 | itarema
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | avarua
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | carauari
# Processing Record 38 of Set 4 | meulaboh
# Processing Record 39 of Set 4 | dalby
# Processing Record 40 of Set 4 | pelotas
# Processing Record 41 of Set 4 | plouzane
# Processing Record 42 of Set 4 | azrow
# City not found. Skipping...
# Processing Record 43 of Set 4 | college
# Processing Record 44 of Set 4 | antsohihy
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | gazli
# Processing Record 47 of Set 4 | vigrestad
# Processing Record 48 of Set 4 | zhuzhou
# Processing Record 49 of Set 4 | ciudad bolivar
# Processing Record 50 of Set 4 | chokurdakh
# Processing Record 1 of Set 5 | martapura
# Processing Record 2 of Set 5 | gushikawa
# Processing Record 3 of Set 5 | buribay
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | mpophomeni
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | syracuse
# Processing Record 8 of Set 5 | morong
# Processing Record 9 of Set 5 | broken hill
# Processing Record 10 of Set 5 | mitu
# Processing Record 11 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 5 | baghdad
# Processing Record 13 of Set 5 | arroyo
# Processing Record 14 of Set 5 | joao pinheiro
# Processing Record 15 of Set 5 | nouadhibou
# Processing Record 16 of Set 5 | rozhyshche
# Processing Record 17 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 5 | rawson
# Processing Record 19 of Set 5 | vao
# Processing Record 20 of Set 5 | midland
# Processing Record 21 of Set 5 | akhtubinsk
# Processing Record 22 of Set 5 | pamanukan
# Processing Record 23 of Set 5 | porto novo
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | sahuaripa
# Processing Record 28 of Set 5 | flin flon
# Processing Record 29 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | christchurch
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | pokhara
# Processing Record 34 of Set 5 | doha
# Processing Record 35 of Set 5 | gayeri
# Processing Record 36 of Set 5 | tari
# Processing Record 37 of Set 5 | aripuana
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | ovre ardal
# Processing Record 40 of Set 5 | teguldet
# Processing Record 41 of Set 5 | shakhrinau
# City not found. Skipping...
# Processing Record 42 of Set 5 | coihaique
# Processing Record 43 of Set 5 | thompson
# Processing Record 44 of Set 5 | kaduy
# Processing Record 45 of Set 5 | gasa
# Processing Record 46 of Set 5 | qurayyat
# Processing Record 47 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | kokstad
# Processing Record 50 of Set 5 | luebo
# Processing Record 1 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | korogwe
# City not found. Skipping...
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | san quintin
# Processing Record 5 of Set 6 | stephenville
# Processing Record 6 of Set 6 | port moresby
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | capljina
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | hokitika
# Processing Record 13 of Set 6 | tiksi
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | umm lajj
# Processing Record 17 of Set 6 | thinadhoo
# Processing Record 18 of Set 6 | annau
# Processing Record 19 of Set 6 | grindavik
# Processing Record 20 of Set 6 | okhotsk
# Processing Record 21 of Set 6 | marsa matruh
# Processing Record 22 of Set 6 | manggar
# Processing Record 23 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 6 | pella
# Processing Record 25 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 6 | lake havasu city
# Processing Record 27 of Set 6 | kalakamati
# Processing Record 28 of Set 6 | kangalassy
# Processing Record 29 of Set 6 | bid
# City not found. Skipping...
# Processing Record 30 of Set 6 | tuy hoa
# Processing Record 31 of Set 6 | disa
# Processing Record 32 of Set 6 | kalianget
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | luderitz
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | tomorkeny
# Processing Record 37 of Set 6 | daru
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | kadyy
# Processing Record 40 of Set 6 | komsomolskiy
# Processing Record 41 of Set 6 | bud
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | petinos
# Processing Record 44 of Set 6 | belaya gora
# Processing Record 45 of Set 6 | sijunjung
# Processing Record 46 of Set 6 | jijiga
# Processing Record 47 of Set 6 | yulara
# Processing Record 48 of Set 6 | ponce
# Processing Record 49 of Set 6 | san isidro
# Processing Record 50 of Set 6 | teahupoo
# Processing Record 1 of Set 7 | cherskiy
# Processing Record 2 of Set 7 | valparaiso
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | saint anthony
# Processing Record 5 of Set 7 | coruripe
# Processing Record 6 of Set 7 | siavonga
# Processing Record 7 of Set 7 | prince rupert
# Processing Record 8 of Set 7 | yerbogachen
# Processing Record 9 of Set 7 | that phanom
# Processing Record 10 of Set 7 | abu kamal
# Processing Record 11 of Set 7 | buenos aires
# Processing Record 12 of Set 7 | pinega
# Processing Record 13 of Set 7 | kalmar
# Processing Record 14 of Set 7 | nieuw amsterdam
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | nara
# Processing Record 17 of Set 7 | mae hong son
# Processing Record 18 of Set 7 | kosonsoy
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | singur
# Processing Record 21 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | khatanga
# Processing Record 23 of Set 7 | callaway
# Processing Record 24 of Set 7 | la asuncion
# Processing Record 25 of Set 7 | senno
# Processing Record 26 of Set 7 | sun city west
# Processing Record 27 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 7 | dehui
# Processing Record 29 of Set 7 | bria
# Processing Record 30 of Set 7 | hobyo
# Processing Record 31 of Set 7 | maceio
# Processing Record 32 of Set 7 | acari
# Processing Record 33 of Set 7 | beloha
# Processing Record 34 of Set 7 | praya
# Processing Record 35 of Set 7 | yangjiang
# Processing Record 36 of Set 7 | wilkie
# Processing Record 37 of Set 7 | guanica
# Processing Record 38 of Set 7 | mountain home
# Processing Record 39 of Set 7 | poltavka
# Processing Record 40 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 7 | angoram
# Processing Record 42 of Set 7 | vanavara
# Processing Record 43 of Set 7 | montepuez
# Processing Record 44 of Set 7 | sarangani
# Processing Record 45 of Set 7 | encruzilhada
# Processing Record 46 of Set 7 | matara
# Processing Record 47 of Set 7 | san policarpo
# Processing Record 48 of Set 7 | katsuura
# Processing Record 49 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 7 | santiago
# Processing Record 1 of Set 8 | aden
# Processing Record 2 of Set 8 | coffs harbour
# Processing Record 3 of Set 8 | vestmannaeyjar
# Processing Record 4 of Set 8 | ati
# Processing Record 5 of Set 8 | ambon
# Processing Record 6 of Set 8 | luanda
# Processing Record 7 of Set 8 | blackwater
# Processing Record 8 of Set 8 | kenai
# Processing Record 9 of Set 8 | altay
# Processing Record 10 of Set 8 | juneau
# Processing Record 11 of Set 8 | moranbah
# Processing Record 12 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 8 | kavieng
# Processing Record 14 of Set 8 | alta gracia
# Processing Record 15 of Set 8 | russell
# Processing Record 16 of Set 8 | baykalovo
# Processing Record 17 of Set 8 | nisia floresta
# Processing Record 18 of Set 8 | esil
# Processing Record 19 of Set 8 | ingham
# Processing Record 20 of Set 8 | riohacha
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | bajil
# Processing Record 24 of Set 8 | auki
# Processing Record 25 of Set 8 | chapais
# Processing Record 26 of Set 8 | blatnica
# Processing Record 27 of Set 8 | harbour breton
# Processing Record 28 of Set 8 | pingliang
# Processing Record 29 of Set 8 | seydi
# Processing Record 30 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 8 | barletta
# Processing Record 32 of Set 8 | karacakoy
# Processing Record 33 of Set 8 | touros
# Processing Record 34 of Set 8 | mackay
# Processing Record 35 of Set 8 | washington
# Processing Record 36 of Set 8 | formosa do rio preto
# Processing Record 37 of Set 8 | kyakhta
# Processing Record 38 of Set 8 | honolulu
# Processing Record 39 of Set 8 | peniche
# Processing Record 40 of Set 8 | smithers
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | zarcero
# Processing Record 43 of Set 8 | erzin
# Processing Record 44 of Set 8 | yinchuan
# Processing Record 45 of Set 8 | kathu
# Processing Record 46 of Set 8 | honningsvag
# Processing Record 47 of Set 8 | gimli
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | aykhal
# Processing Record 50 of Set 8 | fuyu
# Processing Record 1 of Set 9 | lucapa
# Processing Record 2 of Set 9 | jinchang
# Processing Record 3 of Set 9 | oleksandrivka
# Processing Record 4 of Set 9 | richards bay
# Processing Record 5 of Set 9 | nelson bay
# Processing Record 6 of Set 9 | dali
# Processing Record 7 of Set 9 | pundaguitan
# Processing Record 8 of Set 9 | warwick
# Processing Record 9 of Set 9 | portoferraio
# Processing Record 10 of Set 9 | port hardy
# Processing Record 11 of Set 9 | dakar
# Processing Record 12 of Set 9 | awjilah
# Processing Record 13 of Set 9 | lincoln
# Processing Record 14 of Set 9 | koubia
# Processing Record 15 of Set 9 | todos santos
# Processing Record 16 of Set 9 | broome
# Processing Record 17 of Set 9 | zemio
# Processing Record 18 of Set 9 | quirinopolis
# Processing Record 19 of Set 9 | gornozavodsk
# Processing Record 20 of Set 9 | mount gambier
# Processing Record 21 of Set 9 | koslan
# Processing Record 22 of Set 9 | alugan
# Processing Record 23 of Set 9 | ketchikan
# Processing Record 24 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 9 | kamaishi
# Processing Record 26 of Set 9 | ankang
# Processing Record 27 of Set 9 | hambantota
# Processing Record 28 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 9 | kameda
# Processing Record 30 of Set 9 | dawlatabad
# Processing Record 31 of Set 9 | carutapera
# Processing Record 32 of Set 9 | emba
# Processing Record 33 of Set 9 | bonthe
# Processing Record 34 of Set 9 | batouri
# Processing Record 35 of Set 9 | abeokuta
# Processing Record 36 of Set 9 | margate
# Processing Record 37 of Set 9 | segezha
# Processing Record 38 of Set 9 | marevo
# Processing Record 39 of Set 9 | kharan
# Processing Record 40 of Set 9 | myitkyina
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | launceston
# Processing Record 44 of Set 9 | reconquista
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | sinnamary
# Processing Record 47 of Set 9 | iralaya
# Processing Record 48 of Set 9 | sabang
# Processing Record 49 of Set 9 | bluefields
# Processing Record 50 of Set 9 | pisco
# Processing Record 1 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 10 | erdaojiang
# Processing Record 3 of Set 10 | sobolevo
# Processing Record 4 of Set 10 | nishihara
# Processing Record 5 of Set 10 | linjiang
# Processing Record 6 of Set 10 | puerto escondido
# Processing Record 7 of Set 10 | voh
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | buala
# Processing Record 10 of Set 10 | gidrotorf
# Processing Record 11 of Set 10 | antalaha
# Processing Record 12 of Set 10 | cidreira
# Processing Record 13 of Set 10 | hue
# Processing Record 14 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 10 | bubaque
# Processing Record 16 of Set 10 | honiara
# Processing Record 17 of Set 10 | pringsewu
# Processing Record 18 of Set 10 | ambulu
# Processing Record 19 of Set 10 | katha
# City not found. Skipping...
# Processing Record 20 of Set 10 | shenjiamen
# Processing Record 21 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | bull savanna
# Processing Record 23 of Set 10 | beira
# Processing Record 24 of Set 10 | cervo
# Processing Record 25 of Set 10 | riacho de santana
# Processing Record 26 of Set 10 | santa fe
# Processing Record 27 of Set 10 | libenge
# Processing Record 28 of Set 10 | bintulu
# Processing Record 29 of Set 10 | yubari
# Processing Record 30 of Set 10 | lieksa
# Processing Record 31 of Set 10 | januaria
# Processing Record 32 of Set 10 | camacha
# Processing Record 33 of Set 10 | lazaro cardenas
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | wajima
# Processing Record 36 of Set 10 | batamshinskiy
# Processing Record 37 of Set 10 | sao jose da coroa grande
# Processing Record 38 of Set 10 | paranaiba
# Processing Record 39 of Set 10 | omboue
# Processing Record 40 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 10 | saint-francois
# Processing Record 42 of Set 10 | nuevo ideal
# Processing Record 43 of Set 10 | jedrzejow
# Processing Record 44 of Set 10 | groa
# Processing Record 45 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 46 of Set 10 | sorong
# Processing Record 47 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 10 | krasnogorskoye
# Processing Record 49 of Set 10 | sterling
# Processing Record 50 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 11 | monte alegre de minas
# Processing Record 2 of Set 11 | antofagasta
# Processing Record 3 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 11 | nizwa
# Processing Record 5 of Set 11 | sao filipe
# Processing Record 6 of Set 11 | pangnirtung
# Processing Record 7 of Set 11 | olafsvik
# Processing Record 8 of Set 11 | chulman
# Processing Record 9 of Set 11 | hvittingfoss
# Processing Record 10 of Set 11 | ferkessedougou
# Processing Record 11 of Set 11 | zulueta
# Processing Record 12 of Set 11 | barroualie
# City not found. Skipping...
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | kemijarvi
# Processing Record 15 of Set 11 | naryan-mar
# Processing Record 16 of Set 11 | cherdyn
# Processing Record 17 of Set 11 | zhuanghe
# Processing Record 18 of Set 11 | nizhnyaya tavda
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | awassa
# Processing Record 21 of Set 11 | lianran
# Processing Record 22 of Set 11 | elizabeth city
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | tarimoro
# Processing Record 25 of Set 11 | rosetta
# Processing Record 26 of Set 11 | yenangyaung
# Processing Record 27 of Set 11 | imeni stepana razina
# Processing Record 28 of Set 11 | plettenberg bay
# Processing Record 29 of Set 11 | nordborg
# Processing Record 30 of Set 11 | katherine
# Processing Record 31 of Set 11 | mahon
# Processing Record 32 of Set 11 | maraa
# Processing Record 33 of Set 11 | kosmynino
# Processing Record 34 of Set 11 | karaton
# Processing Record 35 of Set 11 | bealanana
# Processing Record 36 of Set 11 | maragogi
# Processing Record 37 of Set 11 | anadyr
# Processing Record 38 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 11 | mao
# Processing Record 40 of Set 11 | popondetta
# Processing Record 41 of Set 11 | lahij
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | ilhabela
# Processing Record 44 of Set 11 | kindu
# Processing Record 45 of Set 11 | kawalu
# Processing Record 46 of Set 11 | mayumba
# Processing Record 47 of Set 11 | bene ayish
# Processing Record 48 of Set 11 | maniitsoq
# Processing Record 49 of Set 11 | manta
# Processing Record 50 of Set 11 | batagay-alyta
# Processing Record 1 of Set 12 | bambous virieux
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | jasper
# Processing Record 4 of Set 12 | simbahan
# Processing Record 5 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 12 | yaan
# Processing Record 7 of Set 12 | grootfontein
# Processing Record 8 of Set 12 | balingasay
# Processing Record 9 of Set 12 | buckeye
# Processing Record 10 of Set 12 | mecca
# Processing Record 11 of Set 12 | manzhouli
# Processing Record 12 of Set 12 | tavricheskoye
# Processing Record 13 of Set 12 | kijang
# Processing Record 14 of Set 12 | lishui
# Processing Record 15 of Set 12 | ballina
# Processing Record 16 of Set 12 | liverpool
# Processing Record 17 of Set 12 | kapit
# Processing Record 18 of Set 12 | neckargemund
# Processing Record 19 of Set 12 | shchuchye
# City not found. Skipping...
# Processing Record 20 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 12 | webster
# Processing Record 22 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 12 | timbiqui
# Processing Record 24 of Set 12 | khorramshahr
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | guhagar
# Processing Record 27 of Set 12 | tautira
# Processing Record 28 of Set 12 | nome
# Processing Record 29 of Set 12 | dicabisagan
# Processing Record 30 of Set 12 | constantine
# Processing Record 31 of Set 12 | pacifica
# Processing Record 32 of Set 12 | pandan
# Processing Record 33 of Set 12 | porto-vecchio
# Processing Record 34 of Set 12 | uyuni
# Processing Record 35 of Set 12 | panzhihua
# Processing Record 36 of Set 12 | rantauprapat
# Processing Record 37 of Set 12 | kieta
# Processing Record 38 of Set 12 | sunbury
# Processing Record 39 of Set 12 | grand gaube
# Processing Record 40 of Set 12 | churapcha
# Processing Record 41 of Set 12 | zhiryatino
# Processing Record 42 of Set 12 | greenwood
# Processing Record 43 of Set 12 | iquitos
# Processing Record 44 of Set 12 | lucea
# Processing Record 45 of Set 12 | svetlyy
# Processing Record 46 of Set 12 | laguna
# Processing Record 47 of Set 12 | namibe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check that over 500 cities are in city_data
print(len(city_data))
# Out:
# 544

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mbandaka      CD   0.0487   18.2603     70.52        97         100
# 1          Kodiak      US  57.7900 -152.4072     63.91        25           0
# 2          Mirnyy      RU  62.5353  113.9611     55.24        81          61
# 3          Dikson      RU  73.5069   80.5464     30.85        95          97
# 4         Aguimes      ES  27.9054  -15.4461     66.83        73          20
# 5  Saint-Ambroise      CA  48.5501  -71.3324     44.89        75           7
# 6         Aklavik      CA  68.2191 -135.0107     33.69        88         100
# 7       Busselton      AU -33.6500  115.3333     64.31        79          72
# 8            Hilo      US  19.7297 -155.0900     91.27        77          20
# 9        Hermanus      ZA -34.4187   19.2345     56.80        72          96
#
#    Wind Speed Current Description                 Date
# 0        1.28          light rain  2022-05-19 01:11:23
# 1       10.36           clear sky  2022-05-19 01:11:24
# 2       13.00       broken clouds  2022-05-19 01:11:24
# 3       15.28     overcast clouds  2022-05-19 01:11:24
# 4       18.41          few clouds  2022-05-19 01:11:25
# 5        2.91           clear sky  2022-05-19 01:11:25
# 6       11.83     overcast clouds  2022-05-19 01:11:26
# 7        7.70       broken clouds  2022-05-19 01:11:26
# 8       12.66          few clouds  2022-05-19 01:11:04
# 9       17.83     overcast clouds  2022-05-19 01:07:49

# %%
# Reorder the columns of the city data df.
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mbandaka      CD   0.0487   18.2603     70.52        97         100
# 1          Kodiak      US  57.7900 -152.4072     63.91        25           0
# 2          Mirnyy      RU  62.5353  113.9611     55.24        81          61
# 3          Dikson      RU  73.5069   80.5464     30.85        95          97
# 4         Aguimes      ES  27.9054  -15.4461     66.83        73          20
# 5  Saint-Ambroise      CA  48.5501  -71.3324     44.89        75           7
# 6         Aklavik      CA  68.2191 -135.0107     33.69        88         100
# 7       Busselton      AU -33.6500  115.3333     64.31        79          72
# 8            Hilo      US  19.7297 -155.0900     91.27        77          20
# 9        Hermanus      ZA -34.4187   19.2345     56.80        72          96
#
#    Wind Speed Current Description
# 0        1.28          light rain
# 1       10.36           clear sky
# 2       13.00       broken clouds
# 3       15.28     overcast clouds
# 4       18.41          few clouds
# 5        2.91           clear sky
# 6       11.83     overcast clouds
# 7        7.70       broken clouds
# 8       12.66          few clouds
# 9       17.83     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
